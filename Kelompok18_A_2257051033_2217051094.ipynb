# %%
class Novel:
    def __init__(self, judul, harga):
        self.judul = judul
        self.harga = harga

    def __str__(self):
        return f"Novel yang Anda beli adalah {self.judul} dengan harga {self.harga}"

list1_misteri = [
    "----Novel Genre Misteri----",
    "1. The Guardians",
    "2. The Devil All the Time",
    "3. Ivana Van Dijk"
]
list2_romance = [
    "----Novel Genre Romance----",
    "1. 1 Kos, 3 Cinta, 7 Keberuntungan",
    "2. Ancika: Dia yang Bersamaku Tahun 1995",
    "3. Dikta & Hukum"
]

list3_horror = [
    "----Novel Genre Horror----",
    "1. Surat dari Kematian",
    "2. Kisah Tanah Jawa",
    "3. Tewasnya Gagak Hitam"
]

list4_comedy = [
    "----Novel Genre Comedy----",
    "1. Ubur-Ubur Lembur",
    "2. Skripsick",
    "3. KambingJantan"
]

def daftar():
 print("Selamat datang di toko novel")
 print()
 print("1. Lihat Daftar Novel mistery")
 print("2. Lihat Daftar Novel romance") 
 print("3. Lihat Daftar Novel horror")
 print("4. Lihat Daftar Novel comedy")
 
print()

daftar_belanja = []
total_harga = 0

while True:
    daftar()
    print()
    pilih = int(input("Pilih nomor menu: "))
    if pilih == 1:
        print("\n".join(list1_misteri))
        while True:
            misteri = input("Pilih novel yang ingin dibeli atau ketik 'selesai' untuk selesai: ")
            if misteri == 'selesai':
                break
            elif misteri in ['1', '2', '3']:
                if misteri == '1':
                    novel = Novel("The Guardians", 50000)
                    total_harga += novel.harga
                    daftar_belanja.append(novel)
                    print(f"Anda membeli {novel.judul}")
                elif misteri == '2':
                    novel = Novel("The Devil All the Time", 75000)
                    total_harga += novel.harga
                    daftar_belanja.append(novel)
                    print(f"Anda membeli {novel.judul}")
                elif misteri == '3':
                    novel = Novel("Ivana Van Dijk", 75000)
                    total_harga += novel.harga
                    daftar_belanja.append(novel)
                    print(f"Anda membeli {novel.judul}")
            else:
                print("Pilihan tidak valid")

        print("Daftar Belanja:")
        for novel in daftar_belanja:
            print(novel)
        print()
        print(f"Total Harga yang harus dibayar: {total_harga}")
        print()
        while True:
            beli_lagi = input("Apakah anda ingin membeli novel lagi? (ya/tidak) ")
            print()
            if beli_lagi == "ya":
                daftar_belanja = []
                total_harga = 0
                break
            elif beli_lagi == "tidak":
                print("-----Terima kasih sudah Belanja-----")
                exit()
            else:
                print("Pilihan tidak valid")
    
    elif pilih == 2:
        print("\n".join(list2_romance))
        while True:
            romance = input("Pilih novel yang ingin dibeli atau ketik 'selesai' untuk selesai: ")
            if romance == 'selesai':
                break
            elif romance in ['1', '2', '3']:
                if romance == '1':
                    novel = Novel(" 1 Kos, 3 Cinta, 7 Keberuntungan", 50000)
                    total_harga += novel.harga
                    daftar_belanja.append(novel)
                    print(f"Anda membeli {novel.judul}")
                elif romance == '2':
                    novel = Novel(" Ancika: Dia yang Bersamaku Tahun 1995", 75000)
                    total_harga += novel.harga
                    daftar_belanja.append(novel)
                    print(f"Anda membeli {novel.judul}")
                elif romance == '3':
                    novel = Novel("Dikta & Hukum", 75000)
                    total_harga += novel.harga
                    daftar_belanja.append(novel)
                    print(f"Anda membeli {novel.judul}")
            else:
                print("Pilihan tidak valid")

        print("Daftar Belanja:")
        for novel in daftar_belanja:
            print(novel)
        print()
        print(f"Total Harga yang harus dibayar: {total_harga}")
        print()
        while True:
            beli_lagi = input("Apakah anda ingin membeli novel lagi? (ya/tidak) ")
            print()
            if beli_lagi == "ya":
                daftar_belanja = []
                total_harga = 0
                break
            elif beli_lagi == "tidak":
                print("-----Terima kasih sudah Belanja-----")
                exit()
            else:
                print("Pilihan tidak valid")
   
    elif pilih == 3:
        print("\n".join(list3_horror))
        while True:
            horor = input("Pilih novel yang ingin dibeli atau ketik 'selesai' untuk selesai: ")
            if horor == 'selesai':
                break
            elif horor in ['1', '2', '3']:
                if horor == '1':
                    novel = Novel("  Surat dari Kematian", 50000)
                    total_harga += novel.harga
                    daftar_belanja.append(novel)
                    print(f"Anda membeli {novel.judul}")
                elif horor == '2':
                    novel = Novel(" Kisah Tanah Jawa", 75000)
                    total_harga += novel.harga
                    daftar_belanja.append(novel)
                    print(f"Anda membeli {novel.judul}")
                elif horor == '3':
                    novel = Novel("Tewasnya Gagak Hitam", 75000)
                    total_harga += novel.harga
                    daftar_belanja.append(novel)
                    print(f"Anda membeli {novel.judul}")
            else:
                print("Pilihan tidak valid")

        print("Daftar Belanja:")
        for novel in daftar_belanja:
            print(novel)
        print()
        print(f"Total Harga yang harus dibayar: {total_harga}")
        print()
        while True:
            beli_lagi = input("Apakah anda ingin membeli novel lagi? (ya/tidak) ")
            print()
            if beli_lagi == "ya":
                daftar_belanja = []
                total_harga = 0
                break
            elif beli_lagi == "tidak":
                print("-----Terima kasih sudah Belanja-----")
                exit()
            else:
                print("Pilihan tidak valid")
                         
    elif pilih == 4:
        print("\n".join(list4_comedy))
        while True:
            comedy = input("Pilih novel yang ingin dibeli atau ketik 'selesai' untuk selesai: ")
            if comedy == 'selesai':
                break
            elif comedy in ['1', '2', '3']:
                if comedy == '1':
                    novel = Novel("  Ubur-Ubur Lembur", 50000)
                    total_harga += novel.harga
                    daftar_belanja.append(novel)
                    print(f"Anda membeli {novel.judul}")
                elif comedy == '2':
                    novel = Novel("  Skripsick", 75000)
                    total_harga += novel.harga
                    daftar_belanja.append(novel)
                    print(f"Anda membeli {novel.judul}")
                elif comedy == '3':
                    novel = Novel( "KambingJantan", 75000)
                    total_harga += novel.harga
                    daftar_belanja.append(novel)
                    print(f"Anda membeli {novel.judul}")
            else:
                print("Pilihan tidak valid")

        print("Daftar Belanja:")
        for novel in daftar_belanja:
            print(novel)
        print()
        print(f"Total Harga yang harus dibayar: {total_harga}")
        print()
        while True:
            beli_lagi = input("Apakah anda ingin membeli novel lagi? (ya/tidak) ")
            print()
            if beli_lagi == "ya":
                daftar_belanja = []
                total_harga = 0
                break
            elif beli_lagi == "tidak":
                print("-----Terima kasih sudah Belanja-----")
                exit()
            else:
                print("Pilihan tidak valid")
    else:
        print("Pilihan tidak valid")
